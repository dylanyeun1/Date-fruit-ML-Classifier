# %%
#libraries
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

df = pd.read_excel('C:\\Users\dylan\Python Projects\ML\Date_Fruit_Datasets\Date_Fruit_Datasets.xlsx')
print(df)
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0    422163  2378.9080    837.8484    645.6693        0.6373  733.1539
# 1    338136  2085.1440    723.8198    595.2073        0.5690  656.1464
# 2    526843  2647.3940    940.7379    715.3638        0.6494  819.0222
# 3    416063  2351.2100    827.9804    645.2988        0.6266  727.8378
# 4    347562  2160.3540    763.9877    582.8359        0.6465  665.2291
# ..      ...        ...         ...         ...           ...       ...
# 893  255403  1925.3650    691.8453    477.1796        0.7241  570.2536
# 894  365924  2664.8230    855.4633    551.5447        0.7644  682.5752
# 895  254330  1926.7360    747.4943    435.6219        0.8126  569.0545
# 896  238955  1906.2679    716.6485    441.8297        0.7873  551.5859
# 897  343792  2289.2720    823.8438    534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# ...

# %%
#Replacing date names w/ numerical values
name_dict = {'BERHI':1, 'DEGLET':2, 'DOKOL': 3, 'IRAQI': 4, 'ROTANA': 6, 'SAFAVI': 7, 'SOGAY': 8}
df['Name'] = df['Class'].map(name_dict)
df.head()
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0  422163   2378.908    837.8484    645.6693        0.6373  733.1539
# 1  338136   2085.144    723.8198    595.2073        0.5690  656.1464
# 2  526843   2647.394    940.7379    715.3638        0.6494  819.0222
# 3  416063   2351.210    827.9804    645.2988        0.6266  727.8378
# 4  347562   2160.354    763.9877    582.8359        0.6465  665.2291
#
#    SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRG  KurtosisRB  \
# 0    0.9947       424428  0.7831        1.2976  ...      2.9574      4.2287
# 1    0.9974       339014  0.7795        1.2161  ...      2.6350      3.1704
# 2    0.9962       528876  0.7657        1.3150  ...      3.8611      4.7192
# 3    0.9948       418255  0.7759        1.2831  ...      8.6136      8.2618
# 4    0.9908       350797  0.7569        1.3108  ...      2.9761      4.4146
#
#      EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  ALLdaub4RG  ALLdaub4RB  \
# ...

# %%
x = df[['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY', 'EQDIASQ', 'SOLIDITY', 'CONVEX_AREA', 'EXTENT', 'ASPECT_RATIO']]
y = df['Name']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
clf = RandomForestClassifier()
clf.fit(x_train, y_train)
#prediction based train data
predictions = clf.predict([[422163, 2378.9080, 837.8484, 645.6693, 0.6373, 733.1539, 0.9947, 424428, 0.7831, 1.2976]])
print(predictions)
#probable outcomes
possibilities = clf.predict_proba([[422163, 2378.9080, 837.8484, 645.6693, 0.6373, 733.1539, 0.9947, 424428, 0.7831, 1.2976]])
print(possibilities)
# Out:
# [1]
# [[0.89 0.   0.   0.1  0.01 0.   0.  ]]
# C:\Users\dylan\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\dylan\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
#Test
testx = clf.predict(x_test)
print(testx)
print(y_test)
# Out:
# [3 2 3 7 4 3 4 3 3 2 2 3 3 3 6 7 8 8 8 2 7 6 3 1 7 3 1 2 1 7 2 3 3 6 3 7 8
#  3 2 7 2 6 7 7 2 2 2 3 3 6 6 1 3 8 3 6 7 3 3 1 1 2 3 2 3 8 2 3 6 8 3 3 6 8
#  6 4 3 6 2 7 3 2 6 6 3 6 3 7 4 3 3 7 7 4 8 3 3 3 3 6 6 4 3 7 7 6 4 6 6 3 7
#  3 6 6 6 2 2 7 7 6 6 3 7 2 7 7 8 2 6 6 3 2 4 6 6 3 6 3 7 4 7 7 7 8 8 7 3 1
#  8 7 8 6 6 2 7 7 8 2 3 6 7 3 8 7 1 4 3 4 3 6 2 7 7 8 8 7 4 2 1 3]
# 331    3
# 638    7
# 326    3
# 848    8
# 39     1
#       ..
# 777    7
# 25     1
# 84     2
# 10     1
# 332    3
# Name: Name, Length: 180, dtype: int64

# %%
#Score
#80-82% accuracy
clf.score(x_test, y_test)
# Out:
# 0.8111111111111111
